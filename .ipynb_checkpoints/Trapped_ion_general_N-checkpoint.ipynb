# %%
import numpy as np
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt

# %%
# Parameters

E=1
dm2 = 1
theta =0.195
sin_2th   = np.sin(2*theta)
cos_2th   = np.cos(2*theta)
omega = dm2/(4.0*E)

bx = omega * np.sin(2 * theta)
by = 0.0
bz = -omega * np.cos(2 * theta)

# number of nu #
N = 4

# %%
def interaction_matrix(N, dm2, E):
    """
    Build Jij = (dm2 / 4E) * (1 - cos(theta_ij)),
    with theta_ij = arccos(0.9) * |i-j|/(N-1).
    """
    i = np.arange(N)
    dij = np.abs(i[:, None] - i[None, :])   # |i-j|
    theta = np.arccos(0.9) * dij / (N - 1)
    J = (dm2 / (4.0 * E)) * (1.0 - np.cos(theta))
    return J

# %%
# -------------------------------------------------
# Add vacuum evolution to an existing circuit
# -------------------------------------------------
def add_vacuum_evolution(qc, n, bx, by, bz, N):
    """
    Add n first-order vacuum steps to the circuit.

    Each step applies:
        exp[-i (bx X_i + by Y_i + bz Z_i)]
    approximately as
        RX(2bx) RY(2by) RZ(2bz)
    on every qubit i.
    """
    for _ in range(n):
        for q in range(N):
            qc.rx(2.0 * bx, q)
            qc.ry(2.0 * by, q)
            qc.rz(2.0 * bz, q)


# -------------------------------------------------
# Add interaction evolution to an existing circuit
# -------------------------------------------------
def add_interaction_evolution(qc, n, J, N):
    """
    Add n first-order interaction steps to the circuit.

    For each pair (i,j), apply
        exp[-i Jij (XX + YY + ZZ)]
    as
        RXX(2 Jij) RYY(2 Jij) RZZ(2 Jij)
    """
    for _ in range(n):
        for i in range(N):
            for j in range(i + 1, N):
                phi = 2.0 * J[i, j]
                qc.rxx(phi, i, j)
                qc.ryy(phi, i, j)
                qc.rzz(phi, i, j)

# %%
def build_full_circuit(qc0, n, bx, by, bz, J, N):
    qc = qc0.copy()

    add_vacuum_evolution(qc, n, bx, by, bz, N)
    add_interaction_evolution(qc, n, J, N)

    qc.measure(range(N), range(N))
    return qc

# %%
# Interaction matrix
J = interaction_matrix(N, dm2, E)

# Initial state prepared outside
qc0 = QuantumCircuit(N, N)
qc0.x(2)# example: qubit 1 is nu_mu, others nu_e
qc0.x(3)

# Build evolved circuit
qc = build_full_circuit(qc0, n=10, bx=bx, by=by, bz=bz, J=J, N=N)

# print(qc.draw())

# %%
# backend = AerSimulator()
# shots = 4096
# n_steps_max = 40

# for n in range(n_steps_max + 1):
#     qc = build_full_circuit(qc0, n=n, bx=bx, by=by, bz=bz, J=J, N=N)
#     tqc = transpile(qc, backend)
#     counts = backend.run(tqc, shots=shots).result().get_counts()
#     print(f"t = {n:2d}, counts = {counts}")

# %%
P_nue_q0 = []
P_numu_q1 = []
P_nue_q0_INV = []
P_numu_q1_INV = []

times = []

backend = AerSimulator()
shots = 4096
n_steps_max = 40

for n in range(n_steps_max + 1):
    qc = build_full_circuit(qc0, n=n, bx=bx, by=by, bz=bz, J=J, N=N)
    tqc = transpile(qc, backend)
    counts = backend.run(tqc, shots=shots).result().get_counts()

    p0_nue = 0.0
    p1_numu = 0.0

    for bitstring, c in counts.items():
        # rightmost bit is qubit 0, next is qubit 1
        q0 = int(bitstring[-1])
        q1 = int(bitstring[-2])

        if q0 == 0:
            p0_nue += c / shots
        if q1 == 1:
            p1_numu += c / shots

    times.append(n)
    P_nue_q0.append(p0_nue)
    P_numu_q1.append(p1_numu)
    P_nue_q0_INV.append(1-p0_nue)
    P_numu_q1_INV.append(1-p1_numu)

#     print(f"t = {n:2d}, counts = {counts}, P(q0=nu_e) = {p0_nue:.4f}, P(q1=nu_mu) = {p1_numu:.4f}")
# Out:
# t =  0, counts = {'1100': 4096}, P(q0=nu_e) = 1.0000, P(q1=nu_mu) = 0.0000
# t =  1, counts = {'1100': 3923, '1110': 41, '0101': 10, '1101': 40, '0100': 45, '1000': 31, '1010': 1, '1001': 3, '0110': 1, '1011': 1}, P(q0=nu_e) = 0.9868, P(q1=nu_mu) = 0.0107
# t =  2, counts = {'1100': 3507, '1000': 137, '0100': 133, '1101': 125, '0111': 4, '1001': 14, '0101': 36, '1110': 111, '0001': 4, '1111': 4, '0110': 9, '1010': 5, '0010': 1, '0000': 6}, P(q0=nu_e) = 0.9543, P(q1=nu_mu) = 0.0327
# t =  3, counts = {'1100': 3020, '1000': 210, '0000': 18, '1101': 219, '0100': 232, '1110': 219, '0101': 74, '1001': 36, '0111': 4, '1111': 15, '1010': 12, '0001': 7, '0110': 24, '0011': 4, '1011': 2}, P(q0=nu_e) = 0.9119, P(q1=nu_mu) = 0.0684
# t =  4, counts = {'1000': 254, '1100': 2513, '1101': 306, '0100': 333, '1001': 55, '0001': 33, '1110': 284, '0111': 22, '0101': 110, '1010': 38, '0110': 50, '1111': 33, '0000': 42, '0010': 10, '0011': 6, '1011': 7}, P(q0=nu_e) = 0.8604, P(q1=nu_mu) = 0.1099
# t =  5, counts = {'1000': 316, '1100': 2209, '0001': 47, '1010': 40, '1001': 65, '0101': 165, '1110': 338, '1101': 325, '0111': 59, '0100': 310, '1111': 54, '0110': 73, '0000': 45, '0011': 18, '0010': 16, '1011': 16}, P(q0=nu_e) = 0.8171, P(q1=nu_mu) = 0.1499
# t =  6, counts = {'0100': 373, '1101': 337, '1100': 2009, '1000': 343, '0000': 65, '0101': 188, '1110': 315, '0110': 81, '1001': 68, '0001': 87, '1011': 21, '0111': 66, '1010': 50, '1111': 50, '0011': 23, '0010': 20}, P(q0=nu_e) = 0.7949, P(q1=nu_mu) = 0.1528
# t =  7, counts = {'1100': 1978, '0000': 54, '1000': 288, '0111': 98, '0100': 364, '1101': 326, '1011': 25, '0001': 95, '0110': 61, '0101': 255, '1110': 303, '1111': 67, '1001': 89, '0011': 24, '0010': 22, '1010': 47}, P(q0=nu_e) = 0.7610, P(q1=nu_mu) = 0.1580
# t =  8, counts = {'1100': 2033, '1101': 316, '0100': 272, '0101': 369, '1110': 251, '0001': 124, '1000': 250, '1011': 21, '0010': 8, '0111': 109, '0110': 72, '1001': 108, '1111': 53, '0000': 56, '0011': 20, '1010': 34}, P(q0=nu_e) = 0.7266, P(q1=nu_mu) = 0.1387
# t =  9, counts = {'1100': 2225, '1000': 183, '0100': 238, '1101': 246, '0111': 118, '0001': 101, '1001': 114, '0101': 486, '1110': 179, '0010': 15, '0000': 27, '0110': 84, '1011': 18, '1010': 18, '0011': 29, '1111': 15}, P(q0=nu_e) = 0.7249, P(q1=nu_mu) = 0.1162
# t = 10, counts = {'1001': 142, '1101': 162, '0100': 177, '0011': 15, '1100': 2410, '1000': 118, '1110': 118, '0101': 604, '0111': 83, '0110': 116, '0001': 80, '1010': 14, '1011': 15, '1111': 14, '0010': 19, '0000': 9}, P(q0=nu_e) = 0.7278, P(q1=nu_mu) = 0.0962
# t = 11, counts = {'0001': 41, '1001': 161, '0011': 19, '1100': 2466, '1000': 40, '0101': 933, '0110': 180, '1101': 66, '0111': 41, '0010': 11, '0100': 64, '1110': 56, '1010': 6, '1011': 8, '0000': 2, '1111': 2}, P(q0=nu_e) = 0.6897, P(q1=nu_mu) = 0.0789
# t = 12, counts = {'0011': 36, '1100': 2409, '0101': 1149, '0110': 236, '1001': 216, '0100': 12, '1101': 7, '0111': 7, '1110': 8, '1010': 6, '1011': 1, '0001': 5, '1000': 4}, P(q0=nu_e) = 0.6531, P(q1=nu_mu) = 0.0718
# t = 13, counts = {'0011': 55, '1100': 2116, '0101': 1350, '0110': 259, '0001': 5, '1010': 13, '1001': 276, '0111': 9, '0010': 1, '1101': 5, '1110': 2, '0100': 4, '1000': 1}, P(q0=nu_e) = 0.5850, P(q1=nu_mu) = 0.0828
# t = 14, counts = {'1100': 1873, '0100': 54, '1101': 65, '0101': 1430, '0110': 214, '0001': 57, '1001': 225, '0111': 48, '1000': 19, '0011': 73, '1110': 22, '0010': 4, '0000': 2, '1111': 2, '1011': 5, '1010': 3}, P(q0=nu_e) = 0.5349, P(q1=nu_mu) = 0.0906
# t = 15, counts = {'0101': 1301, '1100': 1562, '0111': 131, '1001': 225, '0110': 200, '0100': 130, '1101': 129, '1011': 22, '0011': 91, '0001': 162, '1000': 47, '0010': 23, '1110': 46, '1111': 11, '1010': 4, '0000': 12}, P(q0=nu_e) = 0.4941, P(q1=nu_mu) = 0.1289
# t = 16, counts = {'0011': 115, '1100': 1379, '1110': 65, '0101': 1206, '0110': 162, '1101': 154, '0111': 226, '1001': 186, '1000': 63, '1010': 6, '0001': 239, '0100': 172, '1011': 41, '0000': 25, '0010': 34, '1111': 23}, P(q0=nu_e) = 0.4653, P(q1=nu_mu) = 0.1641
# t = 17, counts = {'0100': 222, '0111': 334, '0001': 349, '1110': 71, '0101': 1055, '1011': 50, '1111': 47, '1100': 1152, '0010': 49, '1101': 198, '1001': 151, '0000': 46, '0011': 138, '0110': 163, '1000': 65, '1010': 6}, P(q0=nu_e) = 0.4331, P(q1=nu_mu) = 0.2095
# t = 18, counts = {'0101': 978, '0011': 177, '1100': 1095, '1000': 76, '0111': 365, '1101': 209, '0001': 403, '1001': 146, '0100': 216, '1011': 57, '1111': 58, '0010': 49, '0110': 119, '1110': 67, '0000': 73, '1010': 8}, P(q0=nu_e) = 0.4158, P(q1=nu_mu) = 0.2197
# t = 19, counts = {'1100': 981, '0010': 51, '1001': 139, '0001': 479, '0110': 131, '0101': 987, '0111': 409, '0100': 240, '1000': 51, '1011': 58, '1101': 195, '0011': 205, '0000': 49, '1111': 63, '1110': 55, '1010': 3}, P(q0=nu_e) = 0.3811, P(q1=nu_mu) = 0.2380
# t = 20, counts = {'1110': 49, '0101': 1082, '0100': 201, '1100': 939, '0110': 104, '0111': 449, '1000': 41, '0001': 430, '0011': 197, '0010': 57, '1001': 139, '1111': 69, '0000': 59, '1011': 59, '1101': 219, '1010': 2}, P(q0=nu_e) = 0.3545, P(q1=nu_mu) = 0.2407
# t = 21, counts = {'0111': 374, '0101': 1348, '1100': 830, '0011': 205, '1000': 26, '0100': 178, '1101': 195, '0110': 141, '1111': 36, '0001': 409, '1001': 173, '0000': 40, '1011': 55, '0010': 54, '1110': 22, '1010': 10}, P(q0=nu_e) = 0.3176, P(q1=nu_mu) = 0.2190
# t = 22, counts = {'0101': 1618, '0001': 316, '0011': 205, '1100': 784, '0100': 122, '1101': 129, '0111': 316, '0110': 209, '1001': 243, '1011': 51, '1111': 23, '1000': 8, '1110': 18, '0010': 34, '1010': 8, '0000': 12}, P(q0=nu_e) = 0.2917, P(q1=nu_mu) = 0.2109
# t = 23, counts = {'0101': 2091, '0111': 188, '0110': 254, '0100': 70, '1101': 71, '1001': 272, '0011': 280, '1100': 594, '0001': 182, '0010': 39, '1011': 25, '1110': 4, '1010': 13, '1000': 1, '1111': 6, '0000': 6}, P(q0=nu_e) = 0.2395, P(q1=nu_mu) = 0.1975
# t = 24, counts = {'0011': 365, '1100': 511, '0101': 2339, '0110': 283, '1010': 21, '1001': 350, '0100': 36, '0111': 67, '1101': 29, '0001': 73, '0010': 9, '1011': 8, '1110': 3, '1000': 2}, P(q0=nu_e) = 0.2112, P(q1=nu_mu) = 0.1846
# t = 25, counts = {'0101': 2501, '0110': 337, '1010': 24, '1001': 356, '0011': 384, '1100': 491, '0100': 1, '1101': 1, '0111': 1}, P(q0=nu_e) = 0.2083, P(q1=nu_mu) = 0.1821
# t = 26, counts = {'0011': 397, '1100': 482, '0101': 2431, '1001': 338, '1010': 54, '0110': 293, '1101': 14, '0111': 30, '0001': 28, '1110': 2, '1000': 5, '1011': 2, '0100': 13, '0010': 7}, P(q0=nu_e) = 0.2090, P(q1=nu_mu) = 0.1917
# t = 27, counts = {'1010': 55, '0001': 117, '1001': 242, '0011': 392, '1100': 513, '0101': 2247, '0010': 23, '0111': 118, '0110': 228, '1101': 51, '1011': 25, '1000': 11, '0100': 54, '0000': 5, '1110': 13, '1111': 2}, P(q0=nu_e) = 0.2202, P(q1=nu_mu) = 0.2090
# t = 28, counts = {'1100': 640, '0011': 325, '1110': 30, '0101': 1849, '1001': 162, '0001': 225, '0110': 169, '0111': 260, '1000': 36, '0100': 107, '1101': 104, '1010': 76, '1011': 44, '1111': 16, '0010': 41, '0000': 12}, P(q0=nu_e) = 0.2712, P(q1=nu_mu) = 0.2346
# t = 29, counts = {'0101': 1538, '1010': 79, '0001': 361, '0011': 325, '1100': 686, '1101': 119, '0100': 126, '0111': 342, '0000': 32, '1000': 57, '1011': 69, '0110': 98, '1111': 23, '1001': 125, '0010': 51, '1110': 65}, P(q0=nu_e) = 0.2915, P(q1=nu_mu) = 0.2568
# t = 30, counts = {'0111': 390, '1100': 693, '0011': 309, '0001': 435, '1101': 152, '0101': 1302, '1000': 96, '0110': 66, '0000': 48, '1001': 86, '1011': 67, '1110': 118, '0100': 122, '1010': 93, '1111': 57, '0010': 62}, P(q0=nu_e) = 0.3169, P(q1=nu_mu) = 0.2837
# t = 31, counts = {'0101': 1167, '0011': 333, '1100': 702, '0111': 427, '1000': 121, '0000': 63, '1101': 147, '1011': 79, '0100': 145, '0001': 428, '1111': 61, '1110': 141, '0010': 63, '1001': 66, '1010': 105, '0110': 48}, P(q0=nu_e) = 0.3389, P(q1=nu_mu) = 0.3069
# t = 32, counts = {'0001': 375, '0111': 395, '1100': 729, '1110': 186, '0101': 1157, '1111': 65, '0100': 141, '0000': 77, '0110': 40, '1011': 90, '0011': 298, '1000': 158, '1101': 150, '1010': 112, '1001': 57, '0010': 66}, P(q0=nu_e) = 0.3684, P(q1=nu_mu) = 0.3057
# t = 33, counts = {'0011': 344, '1100': 712, '0010': 52, '1011': 68, '0101': 1257, '0111': 329, '1101': 141, '0001': 339, '1010': 168, '1001': 62, '1000': 161, '0100': 144, '1110': 165, '0000': 49, '1111': 53, '0110': 52}, P(q0=nu_e) = 0.3669, P(q1=nu_mu) = 0.3005
# t = 34, counts = {'0011': 342, '1100': 923, '0101': 1305, '1000': 164, '0001': 279, '1010': 207, '1001': 65, '0110': 42, '0100': 107, '0111': 213, '1110': 158, '1101': 123, '0010': 40, '1111': 28, '1011': 54, '0000': 46}, P(q0=nu_e) = 0.4119, P(q1=nu_mu) = 0.2646
# t = 35, counts = {'1110': 105, '0101': 1417, '1100': 1131, '0011': 412, '0001': 149, '1010': 236, '1000': 127, '0111': 141, '1101': 89, '1001': 61, '1011': 52, '0100': 87, '0010': 36, '0110': 31, '0000': 13, '1111': 9}, P(q0=nu_e) = 0.4312, P(q1=nu_mu) = 0.2495
# t = 36, counts = {'1110': 68, '0101': 1494, '0011': 415, '1100': 1365, '1001': 51, '1010': 331, '1101': 46, '1000': 67, '0111': 67, '1011': 27, '0110': 42, '0001': 64, '0100': 38, '0010': 18, '0000': 3}, P(q0=nu_e) = 0.4717, P(q1=nu_mu) = 0.2363
# t = 37, counts = {'0101': 1417, '1001': 78, '0001': 8, '1010': 457, '1100': 1577, '0011': 459, '0110': 37, '1101': 11, '0111': 5, '0010': 4, '0100': 5, '1000': 16, '1110': 14, '1011': 7, '0000': 1}, P(q0=nu_e) = 0.5154, P(q1=nu_mu) = 0.2400
# t = 38, counts = {'0101': 1386, '0011': 412, '1100': 1757, '0001': 2, '1001': 49, '1010': 462, '0110': 23, '0111': 3, '1011': 1, '1110': 1}, P(q0=nu_e) = 0.5476, P(q1=nu_mu) = 0.2202
# t = 39, counts = {'0011': 359, '1100': 1748, '1110': 55, '0101': 1165, '0001': 41, '1010': 513, '0111': 27, '0100': 32, '1000': 47, '1001': 27, '1011': 12, '0110': 20, '1101': 26, '0010': 21, '1111': 3}, P(q0=nu_e) = 0.5947, P(q1=nu_mu) = 0.2466
# t = 40, counts = {'0011': 305, '1100': 1677, '1000': 143, '1010': 504, '1110': 152, '0101': 974, '1011': 33, '0010': 40, '0100': 58, '0111': 53, '1111': 9, '1101': 68, '0001': 63, '1001': 13, '0000': 3, '0110': 1}, P(q0=nu_e) = 0.6294, P(q1=nu_mu) = 0.2678

# %%
# plt.plot(times[1:], P_nue_q0_INV[1:], marker='o', label='P_inv(qubit 0 = nu_e)')
# plt.plot(times[1:], P_numu_q1_INV[1:], marker='s', label='P_inv(qubit 1 = nu_mu)')
plt.plot(times[1:], P_nue_q0[1:], marker='o', label='P(qubit 0 = nu_e)')
plt.plot(times[1:], P_numu_q1[1:], marker='s', label='P(qubit 1 = nu_mu)')
plt.plot(times[1:], P_nue_q2[1:], marker='o', label='P(qubit 0 = nu_e)')
plt.plot(times[1:], P_numu_q3[1:], marker='s', label='P(qubit 1 = nu_mu)')
plt.xlabel('time step')
plt.ylabel('Probability')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from qiskit import transpile
from qiskit_aer import AerSimulator

initial_bits = [0, 0, 1, 1]

P_inv = [[] for _ in range(N)]
times = []

backend = AerSimulator()
shots = 4096
n_steps_max = 40

for n in range(n_steps_max + 1):
    qc=qc0.copy()
    add_vacuum_evolution(qc, n=n, bx=bx, by=by, bz=bz, N=N)
    add_interaction_evolution(qc, n=n, J=J, N=N)
#     tqc = transpile(qc, backend)
#     counts = backend.run(tqc, shots=shots).result().get_counts()

    qc.measure(range(N), range(N))

    tqc = transpile(qc, backend)
    counts = backend.run(tqc, shots=shots).result().get_counts()

    p_inv_t = [0.0] * N

    for bitstring, c in counts.items():
        prob = c / shots

        for q in range(N):
            bit_q = int(bitstring[-1 - q])
            if bit_q != initial_bits[q]:
                p_inv_t[q] += prob

    times.append(n)

    for q in range(N):
        P_inv[q].append(p_inv_t[q])

    print(
        f"t = {n:2d} | "
        f"q0_inv = {p_inv_t[0]:.4f}, "
        f"q1_inv = {p_inv_t[1]:.4f}, "
        f"q2_inv = {p_inv_t[2]:.4f}, "
        f"q3_inv = {p_inv_t[3]:.4f}"
    )
# Out:
# t =  0 | q0_inv = 0.0000, q1_inv = 0.0000, q2_inv = 0.0000, q3_inv = 0.0000
# t =  1 | q0_inv = 0.0107, q1_inv = 0.0098, q2_inv = 0.0081, q3_inv = 0.0122
# t =  2 | q0_inv = 0.0427, q1_inv = 0.0344, q2_inv = 0.0371, q3_inv = 0.0437
# t =  3 | q0_inv = 0.0872, q1_inv = 0.0815, q2_inv = 0.0667, q3_inv = 0.0974
# t =  4 | q0_inv = 0.1362, q1_inv = 0.1113, q2_inv = 0.1040, q3_inv = 0.1382
# t =  5 | q0_inv = 0.1946, q1_inv = 0.1467, q2_inv = 0.1306, q3_inv = 0.1873
# t =  6 | q0_inv = 0.2236, q1_inv = 0.1545, q2_inv = 0.1707, q3_inv = 0.2168
# t =  7 | q0_inv = 0.2439, q1_inv = 0.1536, q2_inv = 0.1606, q3_inv = 0.2444
# t =  8 | q0_inv = 0.2495, q1_inv = 0.1431, q2_inv = 0.1396, q3_inv = 0.2517
# t =  9 | q0_inv = 0.2722, q1_inv = 0.1245, q2_inv = 0.1228, q3_inv = 0.2805
# t = 10 | q0_inv = 0.2844, q1_inv = 0.0947, q2_inv = 0.0964, q3_inv = 0.2830
# t = 11 | q0_inv = 0.3184, q1_inv = 0.0759, q2_inv = 0.0706, q3_inv = 0.3257
# t = 12 | q0_inv = 0.3579, q1_inv = 0.0654, q2_inv = 0.0710, q3_inv = 0.3530
# t = 13 | q0_inv = 0.4102, q1_inv = 0.0796, q2_inv = 0.0859, q3_inv = 0.4031
# t = 14 | q0_inv = 0.4507, q1_inv = 0.0984, q2_inv = 0.1030, q3_inv = 0.4497
# t = 15 | q0_inv = 0.5110, q1_inv = 0.1379, q2_inv = 0.1384, q3_inv = 0.5034
# t = 16 | q0_inv = 0.5425, q1_inv = 0.1758, q2_inv = 0.1755, q3_inv = 0.5405
# t = 17 | q0_inv = 0.5720, q1_inv = 0.2024, q2_inv = 0.1978, q3_inv = 0.5667
# t = 18 | q0_inv = 0.5901, q1_inv = 0.2175, q2_inv = 0.2300, q3_inv = 0.5825
# t = 19 | q0_inv = 0.6111, q1_inv = 0.2498, q2_inv = 0.2380, q3_inv = 0.6123
# t = 20 | q0_inv = 0.6421, q1_inv = 0.2234, q2_inv = 0.2329, q3_inv = 0.6213
# t = 21 | q0_inv = 0.6821, q1_inv = 0.2422, q2_inv = 0.2405, q3_inv = 0.6731
# t = 22 | q0_inv = 0.7097, q1_inv = 0.2046, q2_inv = 0.2141, q3_inv = 0.6995
# t = 23 | q0_inv = 0.7539, q1_inv = 0.1970, q2_inv = 0.2043, q3_inv = 0.7446
# t = 24 | q0_inv = 0.7852, q1_inv = 0.1775, q2_inv = 0.1890, q3_inv = 0.7720
# t = 25 | q0_inv = 0.7930, q1_inv = 0.1733, q2_inv = 0.1836, q3_inv = 0.7825
# t = 26 | q0_inv = 0.7871, q1_inv = 0.1838, q2_inv = 0.1909, q3_inv = 0.7791
# t = 27 | q0_inv = 0.7651, q1_inv = 0.2131, q2_inv = 0.2202, q3_inv = 0.7595
# t = 28 | q0_inv = 0.7485, q1_inv = 0.2388, q2_inv = 0.2407, q3_inv = 0.7405
# t = 29 | q0_inv = 0.7190, q1_inv = 0.2659, q2_inv = 0.2727, q3_inv = 0.7090
# t = 30 | q0_inv = 0.6743, q1_inv = 0.2886, q2_inv = 0.2974, q3_inv = 0.6741
# t = 31 | q0_inv = 0.6541, q1_inv = 0.2935, q2_inv = 0.3083, q3_inv = 0.6584
# t = 32 | q0_inv = 0.6418, q1_inv = 0.3027, q2_inv = 0.3081, q3_inv = 0.6362
# t = 33 | q0_inv = 0.6067, q1_inv = 0.2920, q2_inv = 0.3057, q3_inv = 0.6079
# t = 34 | q0_inv = 0.5916, q1_inv = 0.2729, q2_inv = 0.2830, q3_inv = 0.5872
# t = 35 | q0_inv = 0.5586, q1_inv = 0.2471, q2_inv = 0.2632, q3_inv = 0.5515
# t = 36 | q0_inv = 0.5322, q1_inv = 0.2419, q2_inv = 0.2515, q3_inv = 0.5251
# t = 37 | q0_inv = 0.4875, q1_inv = 0.2268, q2_inv = 0.2380, q3_inv = 0.4805
# t = 38 | q0_inv = 0.4597, q1_inv = 0.2324, q2_inv = 0.2432, q3_inv = 0.4482
# t = 39 | q0_inv = 0.4036, q1_inv = 0.2400, q2_inv = 0.2422, q3_inv = 0.3989
# t = 40 | q0_inv = 0.3640, q1_inv = 0.2734, q2_inv = 0.2688, q3_inv = 0.3589

# %%
for q in range(N):
    plt.plot(times, P_inv[q], marker='o', label=f'qubit {q}')

plt.xlabel('time step')
plt.ylabel('Inversion probability')
plt.legend()
plt.grid(True)
plt.show()
