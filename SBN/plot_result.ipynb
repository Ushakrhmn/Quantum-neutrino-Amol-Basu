# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
p1 = np.load('4nu_0_20_ideal_prob.npy')
e1 = np.load('4nu_0_20_ideal_e.npy')

e2 = np.load('4nu_0_20_DR_e.npy')
p2 = np.load('4nu_0_20_DR_prob.npy')
s2 = np.load('4nu_0_20_DR_error.npy')

er2 = np.load('4nu_0_20_DR_error_rate.npy')

e3 = np.load('4nu_0_20_DR_approx95.npy')
p3 = np.load('4nu_0_20_DR_approx95_prob.npy')
s3 = np.load('4nu_0_20_DR_approx95_error.npy')

rdr_e = np.load('4nu_0_20_noDR_racetrack_e.npy')
rdr_p = np.load('4nu_0_20_noDR_racetrack_prob.npy')
rdr_sigma = np.load('4nu_0_20_noDR_racetrack_error.npy')

rerror = np.load('4nu_0_20_noDR_racetrack_error_rate.npy')

# %%
print(dr_sigma)
# Out:
# [0.0013218  0.00669716 0.00757699 0.00407793 0.00611837 0.00428691
#  0.00379592 0.00327863 0.00269103 0.00143049 0.00237718 0.00213746
#  0.00160994 0.0019905  0.0016575  0.00185667 0.00296482]

# %%
plt.plot(ideal_e, ideal_p, label='Ideal', color='black', linestyle='--')
plt.errorbar(dr_e, dr_p, yerr=dr_sigma, label='DR', color='blue', fmt='x', markersize=3)
plt.errorbar(nodr_e, nodr_p, yerr=nodr_sigma, label='No DR', color='red', fmt='x', markersize=3)
plt.errorbar(rdr_e, rdr_p, yerr=rdr_sigma, label='DR Racetrack', color='green', fmt='x', markersize=3)

plt.xlabel(r'Time ($1/\mu$)')
plt.ylabel('survival probability')
plt.legend()

plt.savefig('4nu_0_20_DR_race.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.plot(ideal_e, ideal_p, label='Ideal', color='black', linestyle='--')
#       2 plt.errorbar(dr_e, dr_p, yerr=dr_sigma, label='DR', color='blue', fmt='x', markersize=3)
#       3 plt.errorbar(nodr_e, nodr_p, yerr=nodr_sigma, label='No DR', color='red', fmt='x', markersize=3)
#
# NameError: name 'plt' is not defined

# %%
plt.scatter(rdr_e, error)
plt.xlabel(r'Time ($1/\mu$)')
plt.ylabel('Error rate')
# Out:
# Text(0, 0.5, 'Error rate')
