# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 2

loc = ['results/8nu_estimator_Ideal', 'results/8nu_torino_estimator_res2']
names = ["Ideal", "Torino"]

savename = '8nu_torino_estimator'


I_t = np.load(f'{loc[0]}_t.npy')

Torino_t = np.load(f'{loc[1]}_t.npy')

I_evs = np.load(f'{loc[0]}_evs.npy')
Torino_evs = np.load(f'{loc[1]}_evs.npy')

print("Loaded.")
# Out:
# Loaded.

# %%
print(I_evs)
# Out:
# [[0.00000000e+00 1.00000000e+00 0.00000000e+00 1.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   1.00000000e+00 1.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 1.00000000e+00 0.00000000e+00 1.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   1.00000000e+00 1.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.83083120e-03 9.89503234e-01 8.66593433e-03 9.98291224e-01
#   7.32332479e-04 9.76443305e-04 1.22055413e-03 7.93360186e-03
#   9.90845844e-01 9.99877945e-01 0.00000000e+00 1.22055413e-04
#   2.44110826e-04 9.93042841e-01 6.71304772e-03 9.98779446e-01
#   4.88221653e-04 7.32332479e-04 8.54387892e-04 8.17771268e-03
#   9.90967899e-01 9.98047113e-01 1.34260954e-03 6.10277066e-04]
#  [7.81154644e-03 9.60576102e-01 3.16123520e-02 9.95606005e-01
#   9.76443305e-04 3.41755157e-03 3.05138533e-03 3.00256316e-02
#   9.66922983e-01 9.96704504e-01 1.09849872e-03 2.19699744e-03
#   1.58672037e-03 9.71683144e-01 2.67301355e-02 9.96704504e-01
#   1.95288661e-03 1.34260954e-03 3.78371781e-03 3.42975711e-02
#   9.61918711e-01 9.90479678e-01 6.34688148e-03 3.17344074e-03]
#  [1.84303674e-02 9.13950934e-01 6.76186989e-02 9.92432564e-01
#   2.44110826e-03 5.12632735e-03 7.56743562e-03 6.01733187e-02
#   9.32259246e-01 9.93286952e-01 2.31905285e-03 4.39399487e-03
#   2.44110826e-03 9.38972293e-01 5.85865983e-02 9.93164897e-01
#   3.53960698e-03 3.29549616e-03 6.83510314e-03 6.83510314e-02
#   9.24813865e-01 9.77297693e-01 1.50128158e-02 7.68949103e-03]
#  [2.51434151e-02 8.63542048e-01 1.11314537e-01 9.85841572e-01
#   3.90577322e-03 1.02526547e-02 1.14732088e-02 1.05822043e-01
#   8.82704748e-01 9.89137068e-01 3.29549616e-03 7.56743562e-03
#   7.20126938e-03 8.89417796e-01 1.03380935e-01 9.85841572e-01
#   7.07921396e-03 7.07921396e-03 1.25717076e-02 1.14243867e-01
#   8.73184426e-01 9.67533260e-01 2.00170878e-02 1.24496521e-02]]

# %%
for i in range(8): 
   # Plot
   plt.clf()
   plt.plot(I_t, I_evs[:, 3*i], marker='o', linestyle='--', color='blue')
   plt.plot(I_t, I_evs[:, 3*i+1], marker='o', linestyle='--', color='red')
   plt.plot(I_t, I_evs[:, 3*i+1], marker='o', linestyle='--', color='green')

   plt.plot(Torino_t, Torino_evs[:, 3*i], marker='x', linestyle='-', color='blue')
   plt.plot(Torino_t, Torino_evs[:, 3*i+1], marker='x', linestyle='-', color='red')
   plt.plot(Torino_t, Torino_evs[:, 3*i+2], marker='x', linestyle='-', color='green')

   custom_lines = [
      plt.Line2D([0], [0], color='blue', lw=2, label=r'$\nu_e$'),
      plt.Line2D([0], [0], color='red', lw=2, label=r'$\nu_\mu$'),
      plt.Line2D([0], [0], color='green', lw=2, label=r'$\nu_\tau$'),
   ]

# Add the custom legend
plt.legend(handles=custom_lines, loc='upper right')

# Show the plot
plt.show()

# Add the custom legend
plt.legend(handles=custom_lines, loc='upper right')

# Show the plot

plt.xlabel(r"Time ($\mu^{-1}$)")
plt.ylabel(r"P($\nu_0$ → $\nu_i$)")
plt.title(r"$\nu_{0}$ Survival Probability".format(i))
plt.grid(True)

plt.legend()
plt.show()
    # plt.savefig(f"{run_name}_survprob.png")
# Out:
# /var/folders/zz/kbmmgkkj0bn_pv3w4k_0tkph0000gn/T/ipykernel_31262/2951638459.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
